# %%
import pandas as pd

# %%
import plotly.express as px

# %%
kkkfull = pd.read_csv('kkk-ledgers-index.csv', low_memory=False)
dtype={'user_id': int}

# %%
pd.options.display.max_columns=50

# %%
kkkfull
# Out:
#        itemID   Number           fullName Prefix Last Name First Name  \
# 0      K00001     12.0       Fred H Crass    NaN     Crass       Fred
# 1      K00002    501.0   Harold D Adamson    NaN   Adamson     Harold
# 2      K00003    502.0        J E Adamson    NaN   Adamson          J
# 3      K00004    503.0    Albert J Ashade    NaN    Ashade     Albert
# 4      K00005    504.0     Gaylord W Akin    NaN      Akin    Gaylord
# ...       ...      ...                ...    ...       ...        ...
# 29630  K29638  13778.0     James E McCown    NaN    McCown      James
# 29631  K29639  13779.0   William F Marlor    NaN    Marlor    William
# 29632  K29640  13780.0  Albert L Anderson    NaN  Anderson     Albert
# 29633  K29641  13781.0    Albert H Keeney    NaN    Keeney     Albert
# 29634  K29642  13782.0   Andrew P Jackson    NaN   Jackson     Andrew
#
#       Middle Name Suffix residenceAddress1   residenceAddress2  \
# ...

# %%
kkkfull.describe(include='all')
# Out:
#         itemID        Number      fullName Prefix Last Name First Name  \
# count    29635  29633.000000         29635    174     29634      29631
# unique   29635           NaN         24618     14      8518       1989
# top     K00001           NaN  John W Jones    Dr.     Smith       John
# freq         1           NaN             6    123       321       1413
# mean       NaN  14596.902946           NaN    NaN       NaN        NaN
# std        NaN  10541.158265           NaN    NaN       NaN        NaN
# min        NaN     12.000000           NaN    NaN       NaN        NaN
# 25%        NaN   6711.000000           NaN    NaN       NaN        NaN
# 50%        NaN  13350.000000           NaN    NaN       NaN        NaN
# 75%        NaN  20327.000000           NaN    NaN       NaN        NaN
# max        NaN  47802.000000           NaN    NaN       NaN        NaN
#
#        Middle Name Suffix residenceAddress1      residenceAddress2  \
# ...

# %%
kkkfull.head(20)
# Out:
#     itemID  Number          fullName Prefix  Last Name First Name Middle Name  \
# 0   K00001    12.0      Fred H Crass    NaN      Crass       Fred           H
# 1   K00002   501.0  Harold D Adamson    NaN    Adamson     Harold           D
# 2   K00003   502.0       J E Adamson    NaN    Adamson          J           E
# 3   K00004   503.0   Albert J Ashade    NaN     Ashade     Albert           J
# 4   K00005   504.0    Gaylord W Akin    NaN       Akin    Gaylord           W
# 5   K00006   505.0     J B Alderdice    NaN  Alderdice          J           B
# 6   K00007   506.0     J M Alexander    NaN  Alexander          J           M
# 7   K00008   507.0          B B Aley    NaN       Aley          B           B
# 8   K00009   508.0   Dr. Jos H Allen    Dr.      Allen        Jos           H
# 9   K00010   509.0         C R Alley    NaN      Alley          C           R
# 10  K00011   510.0       Edw W Almon    NaN      Almon        Edw           W
# ...

# %%
kkkfull.columns
# Out:
# Index(['itemID', 'Number', 'fullName', 'Prefix', 'Last Name', 'First Name',
#        'Middle Name', 'Suffix', 'residenceAddress1', 'residenceAddress2',
#        'Residence Address', 'Residence Other', 'residenceCity',
#        'residenceState', 'Residence City & State', 'residencePhone',
#        'businessAddress1', 'businessAddress2', 'Business Address',
#        'Business Other', 'businessCity', 'businessState',
#        'Business City & State', 'businessPhone', 'ledger', 'link',
#        'Ledger Link', 'Page', 'pdfFileName', 'symbolExists', 'sNumber',
#        'sErased', 'Notes & Remarks', 'Column 29'],
#       dtype='object')

# %%
kkkfull['Residence City & State'].value_counts()
# Out:
# Residence City & State
# Denver, CO*          15003
# Aurora, CO*            162
# Aurora, CO             101
# Edgewater, CO           40
# Littleton, CO           16
#                      ...
# Port Arthur, TX          1
# Utleyville, CO           1
# Idaho Springs, CO        1
# Las Animas, CO           1
# Fort Logan, CO           1
# Name: count, Length: 177, dtype: int64

# %%
citystate=kkkfull['Residence City & State'].value_counts()

# %%
kkkfull.dtypes
# Out:
# itemID                     object
# Number                    float64
# fullName                   object
# Prefix                     object
# Last Name                  object
# First Name                 object
# Middle Name                object
# Suffix                     object
# residenceAddress1          object
# residenceAddress2          object
# Residence Address          object
# Residence Other            object
# residenceCity              object
# residenceState             object
# Residence City & State     object
# residencePhone             object
# businessAddress1           object
# businessAddress2           object
# Business Address           object
# Business Other             object
# businessCity               object
# businessState              object
# Business City & State      object
# businessPhone              object
# ledger                     object
# link                       object
# Ledger Link                object
# ...

# %%
kkkfull.groupby('Residence City & State')
