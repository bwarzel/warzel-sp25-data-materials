# %%
import pandas as pd

# %%
import plotly.express as px

# %%
kkkfull = pd.read_csv('kkk-ledgers-index.csv', low_memory=False)
dtype={'user_id': int}

# %%
pd.options.display.max_columns=50

# %%
pd.set_option('display.width', None)

# %%
kkkfull[['fullName', 'Residence City & State']]
# Out:
#                 fullName Residence City & State
# 0           Fred H Crass            Denver, CO*
# 1       Harold D Adamson            Denver, CO*
# 2            J E Adamson                    NaN
# 3        Albert J Ashade            Denver, CO*
# 4         Gaylord W Akin            Denver, CO*
# ...                  ...                    ...
# 29630     James E McCown                    NaN
# 29631   William F Marlor                    NaN
# 29632  Albert L Anderson                    NaN
# 29633    Albert H Keeney                    NaN
# 29634   Andrew P Jackson                    NaN
#
# [29635 rows x 2 columns]

# %%
kkknamecity=kkkfull[['fullName', 'Residence City & State']]

# %%
kkknamecity.sample(50)
# Out:
#                       fullName Residence City & State
# 25702           George H Frank                    NaN
# 9710             Albert Nelson            Denver, CO*
# 19723          Hobert A Wilson                    NaN
# 27751     Patrick G Perrington                    NaN
# 3740          Duncan L Jacoway            Denver, CO*
# 12483              Willard Lee            Denver, CO*
# 13017            Earl F Laster            Denver, CO*
# 7600              John V Shinn            Denver, CO*
# 557            Chas O Ringsted            Denver, CO*
# 2190         Cecil Elmer Eagle            Denver, CO*
# 15055  Dr. Geo Alexander Angus              Omaha, NE
# 14333            Harry W Nolte            Denver, CO*
# 5813                Edw R Mays            Denver, CO*
# 8424      Dykes Arthur Pickett            Denver, CO*
# 27025         Lawrence U Bills                    NaN
# 24743          David J Paynter                    NaN
# ...

# %%
citystate=kkkfull['Residence City & State'].value_counts()

# %%
citystate
# Out:
# Residence City & State
# Denver, CO*          15003
# Aurora, CO*            162
# Aurora, CO             101
# Edgewater, CO           40
# Littleton, CO           16
#                      ...
# Port Arthur, TX          1
# Utleyville, CO           1
# Idaho Springs, CO        1
# Las Animas, CO           1
# Fort Logan, CO           1
# Name: count, Length: 177, dtype: int64

# %%
kkkfull[['residenceAddress1', 'residenceAddress2']]
# Out:
#       residenceAddress1   residenceAddress2
# 0           219 E Maple                 NaN
# 1                   NaN  18th & California*
# 2                   NaN                 NaN
# 3           2446 Champa                 NaN
# 4             1241 Penn                 NaN
# ...                 ...                 ...
# 29630               NaN                 NaN
# 29631               NaN                 NaN
# 29632               NaN                 NaN
# 29633               NaN                 NaN
# 29634               NaN                 NaN
#
# [29635 rows x 2 columns]

# %%
addresses=kkkfull[['residenceAddress1', 'residenceAddress2']]

# %%
kkkfull['Last Name'].value_counts()
# Out:
# Last Name
# Smith         321
# Johnson       241
# Miller        241
# Jones         211
# Brown         197
#              ...
# McWhorter       1
# Glessmer        1
# Kilpatrick      1
# Kullgren        1
# Marlor          1
# Name: count, Length: 8518, dtype: int64
