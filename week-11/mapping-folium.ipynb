# %%
#if you have not installed folium yet:
#!pip install folium

import folium
import pandas as pd

# %%
utah_df = pd.read_csv('1871-utah-postmaster-salaries.csv')
print(utah_df.sample(5))
utah_df.dtypes
# Out:
#       PO_Name     County State  PM_Salary   Latitude   Longitude
# 53    Johnson       Kane    UT         12  37.086651 -112.368809
# 87    Parowan       Iron    UT        130  37.841086 -112.830222
# 123     Union  Salt Lake    UT         44  40.606892 -111.874379
# 67      Lynne      Weber    UT         27  41.223000 -111.973830
# 91   Peterson     Morgan    UT         19  41.117999 -111.767715
# PO_Name       object
# County        object
# State         object
# PM_Salary      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
utah_map_empty = folium.Map(location=[40, -111], zoom_start=6)
utah_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45891c959d14f5943838ed327acd6c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45891c959d14f5943838ed327acd6c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45891c959d14f5943838ed327acd6c18 = L.map(
#                 &quot;map_45891c959d14f5943838ed327acd6c18&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f1fc429fc7ba16b6962f226bca177a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07f1fc429fc7ba16b6962f226bca177a.addTo(map_45891c959d14f5943838ed327acd6c18);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_empty_map():
    return folium.Map(location=[40, -111], zoom_start=6)

utah_map = create_empty_map()
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2999df1366dfa0a7912888b05c1643f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2999df1366dfa0a7912888b05c1643f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2999df1366dfa0a7912888b05c1643f = L.map(
#                 &quot;map_e2999df1366dfa0a7912888b05c1643f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73ee3079cbce826cb3f68cb9eae216d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73ee3079cbce826cb3f68cb9eae216d4.addTo(map_e2999df1366dfa0a7912888b05c1643f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = utah_df.isna().sum()
print(missing_values)
# Out:
# PO_Name      0
# County       0
# State        0
# PM_Salary    0
# Latitude     4
# Longitude    4
# dtype: int64

# %%
# Filter out post offices that are missing a latitude value (ie. we don't have any location information about it)
utah_df_locations = utah_df[utah_df['Latitude'].notna()]
print(len(utah_df))
print(len(utah_df_locations))
# Out:
# 136
# 132

# %%
folium.Marker(location=[38.41, -112.339], popup="Adamsville Post Office").add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2999df1366dfa0a7912888b05c1643f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2999df1366dfa0a7912888b05c1643f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2999df1366dfa0a7912888b05c1643f = L.map(
#                 &quot;map_e2999df1366dfa0a7912888b05c1643f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73ee3079cbce826cb3f68cb9eae216d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73ee3079cbce826cb3f68cb9eae216d4.addTo(map_e2999df1366dfa0a7912888b05c1643f);
#
#
#             tile_layer_73ee3079cbce826cb3f68cb9eae216d4.addTo(map_e2999df1366dfa0a7912888b05c1643f);
#
#
#             var marker_f1efa35e5b93a762ac32ecd3b8e93939 = L.marker(
#                 [38.41, -112.339],
#                 {
# }
#             ).addTo(map_e2999df1366dfa0a7912888b05c1643f);
#
#
#         var popup_af93e880447d6ef56b7810a137318aa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f17518550c5b42bd09382f6f0491f77 = $(`&lt;div id=&quot;html_3f17518550c5b42bd09382f6f0491f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville Post Office&lt;/div&gt;`)[0];
#                 popup_af93e880447d6ef56b7810a137318aa7.setContent(html_3f17518550c5b42bd09382f6f0491f77);
#
#
#
#         marker_f1efa35e5b93a762ac32ecd3b8e93939.bindPopup(popup_af93e880447d6ef56b7810a137318aa7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)

# %%
#create a base empty map
utah_map = create_empty_map()

#generate a random row of data
sample_row = utah_df_locations.sample(1)

#use our function on the random row
create_map_markers(sample_row, utah_map)

#display the map
utah_map
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3af038dc9ecf2bdbc94c0cb7273ef7ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3af038dc9ecf2bdbc94c0cb7273ef7ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3af038dc9ecf2bdbc94c0cb7273ef7ba = L.map(
#                 &quot;map_3af038dc9ecf2bdbc94c0cb7273ef7ba&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec3875494482fefbccfe4b00d15fca03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec3875494482fefbccfe4b00d15fca03.addTo(map_3af038dc9ecf2bdbc94c0cb7273ef7ba);
#
#
#             var marker_e90a4f20ef5f66a2bf50baba5407c23a = L.marker(
#                 [37.208316, -113.1882792],
#                 {
# }
#             ).addTo(map_3af038dc9ecf2bdbc94c0cb7273ef7ba);
#
#
#         var popup_74d3fb70650d76cdabc7c1769f2ed6b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edc4550c393ba26ff993a7f3b8129129 = $(`&lt;div id=&quot;html_edc4550c393ba26ff993a7f3b8129129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;124    Virgin City Name: PO_Name, dtype: object&lt;/div&gt;`)[0];
#                 popup_74d3fb70650d76cdabc7c1769f2ed6b0.setContent(html_edc4550c393ba26ff993a7f3b8129129);
#
#
#
#         marker_e90a4f20ef5f66a2bf50baba5407c23a.bindPopup(popup_74d3fb70650d76cdabc7c1769f2ed6b0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah_map)

utah_map
# Out:
# Name of post office: Adamsville
# Name of post office: Alma
# Name of post office: Alpine City
# Name of post office: American Fork
# Name of post office: Bellevue
# Name of post office: Bingham Canyon
# Name of post office: Brigham City
# Name of post office: Bullion
# Name of post office: Cedar City
# Name of post office: Cedar Valley
# Name of post office: Centerville
# Name of post office: Central City
# Name of post office: Chicken Creek
# Name of post office: Clarkston
# Name of post office: Clifton
# Name of post office: Clover Valley
# Name of post office: Coalville
# Name of post office: Corinne
# Name of post office: Cove Creek
# Name of post office: Croydon
# Name of post office: Deseret
# Name of post office: Diamond
# Name of post office: Draper
# Name of post office: Duncans Retreat
# Name of post office: Echo City
# Name of post office: Eden
# Name of post office: Emmaville
# Name of post office: Ephraim
# Name of post office: Eureka
# Name of post office: Fair View
# Name of post office: Fairfield
# Name of post office: Farmington
# Name of post office: Fillmore City
# Name of post office: Forest City
# Name of post office: Fort Hamblin
# Name of post office: Fountain Green
# Name of post office: Franklin
# Name of post office: Goshen
# Name of post office: Grafton
# Name of post office: Grantsville
# Name of post office: Gunnison
# Name of post office: Harrisburg
# Name of post office: Harrisville
# Name of post office: Heber
# Name of post office: Hebron
# Name of post office: Herriman
# Name of post office: Holden
# Name of post office: Hooper
# Name of post office: Huntsville
# Name of post office: Hyde Park
# Name of post office: Hyrum
# Name of post office: Iron City
# Name of post office: Johnson
# Name of post office: Kamas
# Name of post office: Kanab
# Name of post office: Kanarraville
# Name of post office: Kanosh
# Name of post office: Kaysville
# Name of post office: Kelton
# Name of post office: Lake Point
# Name of post office: Leeds
# Name of post office: Lehi City
# Name of post office: Levan
# Name of post office: Liberty
# Name of post office: Logan
# Name of post office: Lynne
# Name of post office: Manti
# Name of post office: Meadow
# Name of post office: Mendon
# Name of post office: Midway
# Name of post office: Mill Creek
# Name of post office: Millville
# Name of post office: Minersville
# Name of post office: Mona
# Name of post office: Monroe
# Name of post office: Morgan
# Name of post office: Moroni
# Name of post office: New Harmony
# Name of post office: Newton
# Name of post office: North Ogden
# Name of post office: Ogden City
# Name of post office: Ophir
# Name of post office: Paradise
# Name of post office: Paragonah
# Name of post office: Parowan
# Name of post office: Payson
# Name of post office: Peoa
# Name of post office: Petersburgh
# Name of post office: Peterson
# Name of post office: Pine Valley
# Name of post office: Pinto
# Name of post office: Plain City
# Name of post office: Pleasant Grove
# Name of post office: Portage
# Name of post office: Providence
# Name of post office: Provo City
# Name of post office: Richfield
# Name of post office: Richmond
# Name of post office: Riverdale
# Name of post office: Rockville
# Name of post office: Saint George
# Name of post office: Salina
# Name of post office: Salt Creek
# Name of post office: Salt Lake City
# Name of post office: Santaquin
# Name of post office: Scipio
# Name of post office: Silver City
# Name of post office: Slatersville
# Name of post office: Smithfield
# Name of post office: South Cottonwood
# Name of post office: Spanish Fork
# Name of post office: Spring City
# Name of post office: Springdale
# Name of post office: Springville
# Name of post office: Stockton
# Name of post office: Stoker
# Name of post office: Summit
# Name of post office: Tokersville
# Name of post office: Tooele
# Name of post office: Uintah
# Name of post office: Union
# Name of post office: Virgin City
# Name of post office: Wales
# Name of post office: Wallsburg
# Name of post office: Wanship
# Name of post office: Wasatch
# Name of post office: Washington
# Name of post office: Wellsville
# Name of post office: West Jordan
# Name of post office: Willard
# Name of post office: Winsor
# Name of post office: Woods Cross
# /var/folders/1x/zwvq_9c13nd4s2lk8pdz1nrw0000gn/T/ipykernel_39709/2508161898.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Name of post office:", row[0])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_784de33f840cb11cc3032417d9be905d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_784de33f840cb11cc3032417d9be905d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_784de33f840cb11cc3032417d9be905d = L.map(
#                 &quot;map_784de33f840cb11cc3032417d9be905d&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2514e95d30b26c83368fd7ea09700536 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2514e95d30b26c83368fd7ea09700536.addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#             var marker_33a43d44fa1f41e30fc5e8ef7fe4d307 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#         var popup_dcd770c39ba37379833a84b6d80a0028 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9df2b5b6dea67378e4f85fe97af32bb7 = $(`&lt;div id=&quot;html_9df2b5b6dea67378e4f85fe97af32bb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_dcd770c39ba37379833a84b6d80a0028.setContent(html_9df2b5b6dea67378e4f85fe97af32bb7);
#
#
#
#         marker_33a43d44fa1f41e30fc5e8ef7fe4d307.bindPopup(popup_dcd770c39ba37379833a84b6d80a0028)
#         ;
#
#
#
#
#             var marker_59a5518d8eb2b2f1bdb860a3566854cd = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#         var popup_a1b4cce8c7551323f86e732d77eb1901 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d80555adb097164d0fcf4dce380d3d71 = $(`&lt;div id=&quot;html_d80555adb097164d0fcf4dce380d3d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_a1b4cce8c7551323f86e732d77eb1901.setContent(html_d80555adb097164d0fcf4dce380d3d71);
#
#
#
#         marker_59a5518d8eb2b2f1bdb860a3566854cd.bindPopup(popup_a1b4cce8c7551323f86e732d77eb1901)
#         ;
#
#
#
#
#             var marker_96514fb54b1c5f9ba47858c1e79796a7 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#         var popup_02d6d29a0364350895a380052063116e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2b79d7b5699c79551336ca67e265439 = $(`&lt;div id=&quot;html_f2b79d7b5699c79551336ca67e265439&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_02d6d29a0364350895a380052063116e.setContent(html_f2b79d7b5699c79551336ca67e265439);
#
#
#
#         marker_96514fb54b1c5f9ba47858c1e79796a7.bindPopup(popup_02d6d29a0364350895a380052063116e)
#         ;
#
#
#
#
#             var marker_605da210dfb5cf5929f68f3d716b17f0 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#         var popup_9ee2f4c6050c0c60e8cb3a0dc09e45b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e8a44bae4706393bf6df67266086142 = $(`&lt;div id=&quot;html_0e8a44bae4706393bf6df67266086142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_9ee2f4c6050c0c60e8cb3a0dc09e45b4.setContent(html_0e8a44bae4706393bf6df67266086142);
#
#
#
#         marker_605da210dfb5cf5929f68f3d716b17f0.bindPopup(popup_9ee2f4c6050c0c60e8cb3a0dc09e45b4)
#         ;
#
#
#
#
#             var marker_325944907962edfc0a14cc8221ea2a34 = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_784de33f840cb11cc3032417d9be905d);
#
#
#         var popup_12d0b580bfacc310d6c48ef32967132b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88f79625573796a2b02c71ba2844a7d2 = $(`&lt;div id=&quot;html_88f79625573796a2b02c71ba2844a7d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_12d0b580bfacc310d6c48ef32967132b.setContent(html_88f79625573796a2b02c71ba2844a7d2);
#
#
#
#         marker_325944907962edfc0a14cc8221ea2a34.bindPopup(popup_12d0b580bfacc310d6c48ef32967132b)
#         ;
#
#
#
#
#             var marker_111cc4002eda3d719d989f9e37692554 = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
utah_map = utah_map_empty

# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
utah_df_locations.apply(
    create_map_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45891c959d14f5943838ed327acd6c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45891c959d14f5943838ed327acd6c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45891c959d14f5943838ed327acd6c18 = L.map(
#                 &quot;map_45891c959d14f5943838ed327acd6c18&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f1fc429fc7ba16b6962f226bca177a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07f1fc429fc7ba16b6962f226bca177a.addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#             tile_layer_07f1fc429fc7ba16b6962f226bca177a.addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#             var marker_14e6f27a246186f3d755a499a26e189d = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#         var popup_07e384b393e195fcf8929bb56c7fbb73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46ae18031b838dc4ae0c351866bc8a00 = $(`&lt;div id=&quot;html_46ae18031b838dc4ae0c351866bc8a00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_07e384b393e195fcf8929bb56c7fbb73.setContent(html_46ae18031b838dc4ae0c351866bc8a00);
#
#
#
#         marker_14e6f27a246186f3d755a499a26e189d.bindPopup(popup_07e384b393e195fcf8929bb56c7fbb73)
#         ;
#
#
#
#
#             var marker_a8363f3b76ac42cc47211d6048ee7a55 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#         var popup_cf58b223e9b608519f663bbea4ce70eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_851f203296bc362ff2b0983a520b1914 = $(`&lt;div id=&quot;html_851f203296bc362ff2b0983a520b1914&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_cf58b223e9b608519f663bbea4ce70eb.setContent(html_851f203296bc362ff2b0983a520b1914);
#
#
#
#         marker_a8363f3b76ac42cc47211d6048ee7a55.bindPopup(popup_cf58b223e9b608519f663bbea4ce70eb)
#         ;
#
#
#
#
#             var marker_371a443adafde0922e98a493cb9da4ba = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#         var popup_9dcdb3fc6fd68995088842782c052cc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5125280f0aaded231d5d7846afae1ca = $(`&lt;div id=&quot;html_f5125280f0aaded231d5d7846afae1ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_9dcdb3fc6fd68995088842782c052cc3.setContent(html_f5125280f0aaded231d5d7846afae1ca);
#
#
#
#         marker_371a443adafde0922e98a493cb9da4ba.bindPopup(popup_9dcdb3fc6fd68995088842782c052cc3)
#         ;
#
#
#
#
#             var marker_f8fd1618229f3065638c5ff4a3d17418 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#         var popup_3f8bad997182031b4f386119ebe052df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e9697006002bb462e6452fbb2b67693 = $(`&lt;div id=&quot;html_8e9697006002bb462e6452fbb2b67693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_3f8bad997182031b4f386119ebe052df.setContent(html_8e9697006002bb462e6452fbb2b67693);
#
#
#
#         marker_f8fd1618229f3065638c5ff4a3d17418.bindPopup(popup_3f8bad997182031b4f386119ebe052df)
#         ;
#
#
#
#
#             var marker_374acedc7c095afba029c45794632b8d = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_45891c959d14f5943838ed327acd6c18);
#
#
#         var popup_22c20f0b416b36e0cbf4bf654ca7aa36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_881ace564041b364efe1f32049dbe3c9 = $(`&lt;div id=&quot;html_881ace564041b364efe1f32049dbe3c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_22c20f0b416b36e0cbf4bf654ca7aa36.setContent(html_881ace564041b364efe1f32049dbe3c9);
#
#
#
#         marker_374acedc7c095afba029c45794632b8d.bindPopup(popup_22c20f0b416b36e0cbf4bf654ca7aa36)
#         ;
#
#
#
#
#             var

# %%
# Melanie Walsh function we will edit:
#def create_ICE_map_markers(row, map_name):
#    folium.CircleMarker(location=[row['lat'], row['lon']], raidus=100, fill=True,
#                       popup=folium.Popup(f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}", max_width=200),
#                       tooltip=f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}"
#                       ).add_to(map_name)

def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=6,
                       fill=True,
                       popup=folium.Popup(f"{row['PO_Name'].title()}", max_width=200),
                       tooltip=f"{row['PO_Name'].title()}"
                       ).add_to(map_name)

# %%
# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(create_circle_markers, map_name=utah_map, axis="columns")

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77490c1aa8d3faa4dc5739b44c5bdfc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77490c1aa8d3faa4dc5739b44c5bdfc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77490c1aa8d3faa4dc5739b44c5bdfc4 = L.map(
#                 &quot;map_77490c1aa8d3faa4dc5739b44c5bdfc4&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2971d133d91cc13d8409ad73130a8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b2971d133d91cc13d8409ad73130a8b.addTo(map_77490c1aa8d3faa4dc5739b44c5bdfc4);
#
#
#             var circle_marker_aba3fbbbaec9e8d0feae8ee943654817 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77490c1aa8d3faa4dc5739b44c5bdfc4);
#
#
#         var popup_927c74e4016b9bad8e8851c292147ccb = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_fd770952e79a0ef3af1ccb12d039f764 = $(`&lt;div id=&quot;html_fd770952e79a0ef3af1ccb12d039f764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_927c74e4016b9bad8e8851c292147ccb.setContent(html_fd770952e79a0ef3af1ccb12d039f764);
#
#
#
#         circle_marker_aba3fbbbaec9e8d0feae8ee943654817.bindPopup(popup_927c74e4016b9bad8e8851c292147ccb)
#         ;
#
#
#
#
#             circle_marker_aba3fbbbaec9e8d0feae8ee943654817.bindTooltip(
#                 `&lt;div&gt;
#                      Adamsville
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ae309633405c8a29bf5012e1ad4d4439 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77490c1aa8d3faa4dc5739b44c5bdfc4);
#
#
#         var popup_a8135c01dd6ec9dc5c6b87d80617a116 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4ca7768cc8469443d5610ae59099c956 = $(`&lt;div id=&quot;html_4ca7768cc8469443d5610ae59099c956&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_a8135c01dd6ec9dc5c6b87d80617a116.setContent(html_4ca7768cc8469443d5610ae59099c956);
#
#
#
#         circle_marker_ae309633405c8a29bf5012e1ad4d4439.bindPopup(popup_a8135c01dd6ec9dc5c6b87d80617a116)
#         ;
#
#
#
#
#             circle_marker_ae309633405c8a29bf5012e1ad4d4439.bindTooltip(
#                 `&lt;div&gt;
#                      Alma
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_193ce48ee5ae4d41518ee8d3c33d8baf = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77490c1aa8d3faa4dc5739b44c5bdfc4);
#
#
#         var popup_1c831ee9955d4b93a9f340aef17d8ff0 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_3e0518c729fc12b729c7ee5321e6ea16 = $(`&lt;div id=&quot;html_3e0518c729fc12b729c7ee5321e6ea16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_1c831ee9955d4b93a9f340aef17d8ff0.setContent(html_3e0518c729fc12b729c7ee5321e6ea16);

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=6,
                       color='red',
                       fill=True,
                       fill_color='blue',
                       fill_opacity=0.8,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de81f9c1510f3c109d263c0ab251d23f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de81f9c1510f3c109d263c0ab251d23f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de81f9c1510f3c109d263c0ab251d23f = L.map(
#                 &quot;map_de81f9c1510f3c109d263c0ab251d23f&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bea380ef6e4d3afb46391eedcd5cd061 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bea380ef6e4d3afb46391eedcd5cd061.addTo(map_de81f9c1510f3c109d263c0ab251d23f);
#
#
#             var circle_marker_48d35044cf2fe1fc2c2a751260f49e17 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de81f9c1510f3c109d263c0ab251d23f);
#
#
#         var popup_e1ebde0873e2e62845d1543b26fa4806 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f4beca4121db26b882812517cb1db937 = $(`&lt;div id=&quot;html_f4beca4121db26b882812517cb1db937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_e1ebde0873e2e62845d1543b26fa4806.setContent(html_f4beca4121db26b882812517cb1db937);
#
#
#
#         circle_marker_48d35044cf2fe1fc2c2a751260f49e17.bindPopup(popup_e1ebde0873e2e62845d1543b26fa4806)
#         ;
#
#
#
#
#             circle_marker_48d35044cf2fe1fc2c2a751260f49e17.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_690b28b041ca708faea103db0f747cd2 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de81f9c1510f3c109d263c0ab251d23f);
#
#
#         var popup_a576aaf4656fdc8b3592455965e58ca8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_7f31bada7ebe93ce3e8c26a64f2bf316 = $(`&lt;div id=&quot;html_7f31bada7ebe93ce3e8c26a64f2bf316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_a576aaf4656fdc8b3592455965e58ca8.setContent(html_7f31bada7ebe93ce3e8c26a64f2bf316);
#
#
#
#         circle_marker_690b28b041ca708faea103db0f747cd2.bindPopup(popup_a576aaf4656fdc8b3592455965e58ca8)
#         ;
#
#
#
#
#             circle_marker_690b28b041ca708faea103db0f747cd2.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1545731dcbcdae567ac318eda8044747 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de81f9c1510f3c109d263c0ab251d23f);
#
#
#         var popup_bb49cc7fc66cbf298b6e9cbf558829dd = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_cac7e753108dd8b1cfb84fb471f7d494 = $(`&lt;div id=&quot;html_cac7e753108dd8b1cfb84fb471f7d494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_bb49cc7fc66cbf298b6e9cbf558829dd.setContent(html_cac7e753108

# %%
# make new function to create circle markers sized by postmaster salary
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary'],
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92da9b0c9e78e18128ef9c4f0ddccbc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92da9b0c9e78e18128ef9c4f0ddccbc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92da9b0c9e78e18128ef9c4f0ddccbc8 = L.map(
#                 &quot;map_92da9b0c9e78e18128ef9c4f0ddccbc8&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_607a97763dc43d30af04819f803a6d04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607a97763dc43d30af04819f803a6d04.addTo(map_92da9b0c9e78e18128ef9c4f0ddccbc8);
#
#
#             var circle_marker_1759ef0b71433f74ffa9dfcfdf370eae = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92da9b0c9e78e18128ef9c4f0ddccbc8);
#
#
#         var popup_717f9e550d8999d34c76108d0f617acd = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_fbe20bd74edc11051acd799d252bd639 = $(`&lt;div id=&quot;html_fbe20bd74edc11051acd799d252bd639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_717f9e550d8999d34c76108d0f617acd.setContent(html_fbe20bd74edc11051acd799d252bd639);
#
#
#
#         circle_marker_1759ef0b71433f74ffa9dfcfdf370eae.bindPopup(popup_717f9e550d8999d34c76108d0f617acd)
#         ;
#
#
#
#
#             circle_marker_1759ef0b71433f74ffa9dfcfdf370eae.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ba5dd4f940fdd7a2c887611903da0221 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92da9b0c9e78e18128ef9c4f0ddccbc8);
#
#
#         var popup_669c56ec589b18fc59cd93e09cd41b18 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_fc50c20e73409758af13b4994a3a3bd6 = $(`&lt;div id=&quot;html_fc50c20e73409758af13b4994a3a3bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_669c56ec589b18fc59cd93e09cd41b18.setContent(html_fc50c20e73409758af13b4994a3a3bd6);
#
#
#
#         circle_marker_ba5dd4f940fdd7a2c887611903da0221.bindPopup(popup_669c56ec589b18fc59cd93e09cd41b18)
#         ;
#
#
#
#
#             circle_marker_ba5dd4f940fdd7a2c887611903da0221.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1abcd3ac6634535a0d5bc5382435ab68 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92da9b0c9e78e18128ef9c4f0ddccbc8);
#
#
#         var popup_be00cf18b69c2c5156b374bd88e11d9d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_d92c7ff794b9f87bcbff14573abfb988 = $(`&lt;div id=&quot;html_d92c7ff794b9f87bcbff14573abfb988&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_be00cf18b69c2c5156b374bd88e11d9d.set

# %%
# make new function to create circle markers sized by postmaster salary - this time adjusting the radius size in pixels to make it more legible
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary']/100,
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62f4d5937c833369d082e651f346b3a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62f4d5937c833369d082e651f346b3a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62f4d5937c833369d082e651f346b3a4 = L.map(
#                 &quot;map_62f4d5937c833369d082e651f346b3a4&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2d27a9c96c21df83a9ba1eaf9761d46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2d27a9c96c21df83a9ba1eaf9761d46.addTo(map_62f4d5937c833369d082e651f346b3a4);
#
#
#             var circle_marker_5850d80ec3ad2ec7214e3203b500a43a = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f4d5937c833369d082e651f346b3a4);
#
#
#         var popup_ba294469e208ee0f6f10df6bc95e7334 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f98f762b2dd44710c2a0e76470d8e8b7 = $(`&lt;div id=&quot;html_f98f762b2dd44710c2a0e76470d8e8b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_ba294469e208ee0f6f10df6bc95e7334.setContent(html_f98f762b2dd44710c2a0e76470d8e8b7);
#
#
#
#         circle_marker_5850d80ec3ad2ec7214e3203b500a43a.bindPopup(popup_ba294469e208ee0f6f10df6bc95e7334)
#         ;
#
#
#
#
#             circle_marker_5850d80ec3ad2ec7214e3203b500a43a.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2b71924afcfc617b8b72feb15951f302 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f4d5937c833369d082e651f346b3a4);
#
#
#         var popup_c5b8aadcfdd206a8008ffdb451e99192 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_0d582c596156253d55563abd5bac8a3d = $(`&lt;div id=&quot;html_0d582c596156253d55563abd5bac8a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_c5b8aadcfdd206a8008ffdb451e99192.setContent(html_0d582c596156253d55563abd5bac8a3d);
#
#
#
#         circle_marker_2b71924afcfc617b8b72feb15951f302.bindPopup(popup_c5b8aadcfdd206a8008ffdb451e99192)
#         ;
#
#
#
#
#             circle_marker_2b71924afcfc617b8b72feb15951f302.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_dba985d21c984a57fe054b25562b91f4 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f4d5937c833369d082e651f346b3a4);
#
#
#         var popup_b196267e106dde794966fddfa4bc9a82 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9fb91abd9c0f6715e5c124472bf91d0b = $(`&lt;div id=&quot;html_9fb91abd9c0f6715e5c124472bf91d0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_b196267e106dde794966fddfa4bc9a8

# %%
utah_df_locations.describe()
# Out:
#          PM_Salary    Latitude   Longitude
# count   132.000000  132.000000  132.000000
# mean    101.098485   39.907743 -112.161190
# std     344.225580    1.505091    0.593117
# min       4.000000   37.006375 -113.819415
# 25%      12.000000   38.874099 -112.379230
# 50%      22.000000   40.380926 -111.973830
# 75%      70.000000   41.080917 -111.819912
# max    3600.000000   42.187500 -111.281850

# %%
def add_salary_buckets(salary):
    # Create a new column for the salary bucket
    if salary < 50:
        bucket = 'Low Salary'
    elif salary >= 50 and salary < 250:
        bucket = 'Medium Salary'
    elif salary >= 250 and salary < 1000:
        bucket = 'High Salary'
    else:
        bucket = 'Very High Salary'
    return bucket

# %%
#test out the function
add_salary_buckets(2000)
# Out:
# 'Very High Salary'

# %%
utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
utah_df_locations.head()
# Out:
# /var/folders/1x/zwvq_9c13nd4s2lk8pdz1nrw0000gn/T/ipykernel_39709/2959544325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
#          PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0     Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1           Alma       Weber    UT         12  41.248833 -112.078275
# 2    Alpine City        Utah    UT         27  40.453283 -111.777986
# 3  American Fork        Utah    UT        130  40.375229 -111.796320
# 4       Bellevue  Washington    UT         20  37.340815 -113.274116
#
#    Salary_Bucket
# 0     Low Salary
# 1     Low Salary
# 2     Low Salary
# 3  Medium Salary
# 4     Low Salary

# %%
# create a function to add marker sizes based on the salary bucket
def add_marker_sizes(category):
    if category == 'Low Salary':
        return 4
    elif category == 'Medium Salary':
        return 8
    elif category == 'High Salary':
        return 12
    else:
        return 16

#test out the function
add_marker_sizes('High Salary')
# Out:
# 12

# %%
utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
utah_df_locations.head(10)
# Out:
# /var/folders/1x/zwvq_9c13nd4s2lk8pdz1nrw0000gn/T/ipykernel_39709/3689819186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
#            PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0       Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1             Alma       Weber    UT         12  41.248833 -112.078275
# 2      Alpine City        Utah    UT         27  40.453283 -111.777986
# 3    American Fork        Utah    UT        130  40.375229 -111.796320
# 4         Bellevue  Washington    UT         20  37.340815 -113.274116
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# 7     Brigham City   Box Elder    UT        400  41.510213 -112.015501
# 8          Bullion       Piute    UT         12  38.410000 -112.339000
# 9       Cedar City        Iron    UT        200  37.676644 -113.057171
# 10    Cedar Valley        Utah    UT         13  40.327171 -112.104385
#
#     Salary_Bucket  Marker_Size
# 0      Low Salary            4
# 1      Low Salary            4
# 2      Low Salary            4
# 3   Medium Salary            8
# 4      Low Salary            4
# 5      Low Salary            4
# 7     High Salary           12
# 8      Low Salary            4
# 9   Medium Salary            8
# 10     Low Salary            4

# %%
# make new function to create circle markers sized by salary category
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['Marker_Size'],
                       fill=True,
                       opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03277ad3bba7f92439e2098f371cf074 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03277ad3bba7f92439e2098f371cf074&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03277ad3bba7f92439e2098f371cf074 = L.map(
#                 &quot;map_03277ad3bba7f92439e2098f371cf074&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c834eba274cab1183a189a27ed0e483c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c834eba274cab1183a189a27ed0e483c.addTo(map_03277ad3bba7f92439e2098f371cf074);
#
#
#             var circle_marker_667dd4033e2a8632c46ae1e2e853bccb = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03277ad3bba7f92439e2098f371cf074);
#
#
#         var popup_a6dd1321f6fbf4452b05e7431a0068e1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_a3f907ade1472dd209b58db8ace70f1a = $(`&lt;div id=&quot;html_a3f907ade1472dd209b58db8ace70f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_a6dd1321f6fbf4452b05e7431a0068e1.setContent(html_a3f907ade1472dd209b58db8ace70f1a);
#
#
#
#         circle_marker_667dd4033e2a8632c46ae1e2e853bccb.bindPopup(popup_a6dd1321f6fbf4452b05e7431a0068e1)
#         ;
#
#
#
#
#             circle_marker_667dd4033e2a8632c46ae1e2e853bccb.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_0867cd92e484da4ce46f421a92226f7e = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03277ad3bba7f92439e2098f371cf074);
#
#
#         var popup_56beb745c26549f090f7b8ed434f461f = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_744a4d19898d30804ac4d7b98e0df384 = $(`&lt;div id=&quot;html_744a4d19898d30804ac4d7b98e0df384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_56beb745c26549f090f7b8ed434f461f.setContent(html_744a4d19898d30804ac4d7b98e0df384);
#
#
#
#         circle_marker_0867cd92e484da4ce46f421a92226f7e.bindPopup(popup_56beb745c26549f090f7b8ed434f461f)
#         ;
#
#
#
#
#             circle_marker_0867cd92e484da4ce46f421a92226f7e.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fa85d2c1245740c8dfdec6427de4879e = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03277ad3bba7f92439e2098f371cf074);
#
#
#         var popup_f011eba139fdd68ef4262636f6485c12 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_d8fc44665d33e21dad261dc3b8c98d3b = $(`&lt;div id=&quot;html_d8fc44665d33e21dad261dc3b8c98d3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_f011eba139fdd68ef4262636f6485c12.setCon

# %%
official_df = pd.read_csv('1877-official-register.csv')
print(official_df.sample(5))
official_df.dtypes
# Out:
#                Name State                  Department  \
# 94     Grand Island    NE  Department of the Interior
# 577           Salem    OR         Treasury Department
# 294         Carroll    MT                    Judicial
# 356      Vermillion    SD                    Judicial
# 121  Salt Lake City    UT  Department of the Interior
#
#                                              Type  People   Latitude  \
# 94                  General Land Office Registers       1  40.926396
# 577             Internal Revenue_Deputy Collector       1  44.942898
# 294                                  Commissioner       1  47.573611
# 356                                  Commissioner       1  42.779442
# 121  Governors and Secretaries of the Territories       2  40.760779
#
#       Longitude
# 94   -98.342012
# 577 -123.035096
# 294 -108.372778
# 356  -96.929210
# 121 -111.891047
# Name           object
# State          object
# Department     object
# Type           object
# People          int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
def create_empty_map():
    return folium.Map(location=[40,-100], zoom_start=6)

official_map = create_empty_map()
official_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c88198fc0ac30369359947344999a53b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c88198fc0ac30369359947344999a53b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c88198fc0ac30369359947344999a53b = L.map(
#                 &quot;map_c88198fc0ac30369359947344999a53b&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38f049a2cd13fe3822709bfef85b0f6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38f049a2cd13fe3822709bfef85b0f6f.addTo(map_c88198fc0ac30369359947344999a53b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = official_df.isna().sum()
print(missing_values)
# Out:
# Name          0
# State         0
# Department    0
# Type          0
# People        0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, official_map):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['People']).add_to(official_map)

# %%
official_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c88198fc0ac30369359947344999a53b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c88198fc0ac30369359947344999a53b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c88198fc0ac30369359947344999a53b = L.map(
#                 &quot;map_c88198fc0ac30369359947344999a53b&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38f049a2cd13fe3822709bfef85b0f6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38f049a2cd13fe3822709bfef85b0f6f.addTo(map_c88198fc0ac30369359947344999a53b);
#
#
#             tile_layer_38f049a2cd13fe3822709bfef85b0f6f.addTo(map_c88198fc0ac30369359947344999a53b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
