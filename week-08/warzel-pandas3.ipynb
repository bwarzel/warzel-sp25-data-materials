# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
utah_df=pd.read_csv('utah-census-1880.csv')

# %%
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...

# %%
utah_df.sample(12)
# Out:
#                               key   page  line  district  \
# 41772        0489B_20_ALEXANDER_8  0489B    20      8192
# 137101        0480C_16_MESSERVY_5  0480C    16     25600
# 33994        0392B_25_SCHRODER_42  0392B    25      6144
# 86385         0034B_41_WOODARD_18  0034B    41     18688
# 23622         0070B_39_HARDING_13  0070B    39      1281
# 191              0122A_23_BATT_22  0122A    23      2048
# 102848    0415A_39_CHRISTENSEN_41  0415A    39     16640
# 9593    0218D_3_CHRISTOFFERSEN_18  0218D     3      3072
# 78306          0285D_21_NICKLE_60  0285D    21     14848
# 80204           0306C_3_ASTILL_16  0306C     3     15105
# 9122          0213D_3_PETERSON_49  0213D     3      3072
# 49859            0507A_4_WELLS_18  0507A     4     17920
#
#                                 location     county  household  family  \
# 41772                   Deseret Precinct    MILLARD         42      44
# 137101           Plain City and Precinct      WEBER        115     115
# ...

# %% [markdown]
# **observations and questions**
#
# -what is the 'household' cateogry counting? is it amount of people in household or did they assign numbers to each household?
#
# -same question with the 'family' category. these two seem to only ever be a few numbers off from each other
#
# -contains questions about parents' birthplace
#
# -contains questions about 'disabilities' like insantiy
#
# -contains information on education level
#
# -'birthmonth' and 'race' fields are stored as integers?

# %%
utah_df = utah_df.rename(columns={'birthstate' : 'birthplace'})

# %%
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...

# %%
def replace_married(some_string):
    if some_string=='m' :
        return 'married'
    elif some_string=='s' :
        return 'single'
    elif some_string=='w' :
        return 'widowed'

# %%
utah_df["marrystatus"].apply(replace_married)
# Out:
# 0         married
# 1         married
# 2         married
# 3         married
# 4          single
#            ...
# 142706       None
# 142707       None
# 142708    widowed
# 142709     single
# 142710     single
# Name: marrystatus, Length: 142711, dtype: object

# %%
utah_df['marrystatus']=utah_df["marrystatus"].apply(replace_married)

# %%
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...
